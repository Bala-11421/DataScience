# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("preplacementdata.csv")

# %%
dataset
# Out:
#      Unnamed: 0  sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  \
# 0             0    1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1             1    2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2             2    3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3             3    4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4             4    5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..          ...    ...    ...    ...       ...      ...    ...       ...
# 210         210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 211         211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212         212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213         213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214         214  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0        0
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# to check inbuilt functon using dir()

# %%
dataset.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset.corr()
#
# File ~\anaconda3\envs\AiMl\lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\envs\AiMl\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
dataset.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset.cov()
#
# File ~\anaconda3\envs\AiMl\lib\site-packages\pandas\core\frame.py:11191, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11189 cols = data.columns
#   11190 idx = cols.copy()
# > 11191 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11193 if notna(mat).all():
#   11194     if min_periods is not None and min_periods > len(mat):
#
# File ~\anaconda3\envs\AiMl\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...
